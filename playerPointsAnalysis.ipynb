# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/box_scores10242023')

# %%
df.head()
# Out:
#    Unnamed: 0            PLAYER    MP  FG  FGA    FG%  3P  3PA    3P%  FT  \
# 0           0  D'Angelo Russell  3611   4   12  0.333   2    5  0.400   1
# 1           1     Anthony Davis  3409   6   17  0.353   1    2  0.500   4
# 2           2     Austin Reaves  3120   4   11  0.364   1    2  0.500   5
# 3           3    Taurean Prince  2953   6    8  0.750   4    6  0.667   2
# 4           4      LeBron James  2900  10   16  0.625   1    4  0.250   0
#
#    ...  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  ORtg  DRtg   BPM
# 0  ...  13.3   6.2  26.0   1.4   0.0  18.9  19.2    91   125  -6.9
# 1  ...  24.6  13.1  17.3   0.0   4.9   9.6  26.6   100   122  -2.2
# 2  ...  15.3  14.3  17.6   3.2   0.0  12.4  22.4   113   121   1.6
# 3  ...   8.0   5.6   5.1   0.0   2.8  10.1  14.5   175   128  10.9
# 4  ...  29.0  15.4  33.9   1.7   0.0   0.0  24.8   141   122  12.4
#
# [5 rows x 37 columns]

# %%
df['bins'] = pd.cut(df['PTS'],
					bins = [0,10,20,30,40,50,100], 
					labels = ["0-10", "11-20", "21-30", "31-40", "41-50", "50+"])

a = df.groupby('bins', observed = True).size()
a.plot.pie(figsize=(4,4), autopct='%1.0f%%')
plt.title("Player Points")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.scatter(df['MP'], df['PTS'])
plt.title("Minutes Played vs Field Goal Percentage")
plt.xlabel("Minutes Played")
plt.ylabel("Number of Points")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.scatter(df['FG%'], df['PTS'])
plt.title("Player Points vs Field Goal Percentage")
plt.xlabel("Field Goal %")
plt.ylabel("Number of Points")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.scatter(df['FGA'], df['PTS'])
plt.title("Player Points vs Field Goal Attempts")
plt.xlabel("Number of Field Goal Attempts")
plt.ylabel("Number of Points")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.scatter(df['ORtg'], df['PTS'])
plt.title("Player Points vs Offensive Rating")
plt.xlabel("Offensive Rating")
plt.ylabel("Number of Points")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.scatter(df['ORtg'], df['FG%'])
plt.title("Offensive Rating vs Field Goal Percentage")
plt.xlabel("Offensive Rating")
plt.ylabel("Field Goal %")
plt.show()
